# %% [markdown]
# <a href="https://colab.research.google.com/github/mahi-siri/python-practice/blob/main/variable_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l=input()
vowels,consonants=0,0
for cha in l.lower():
  if cha in "aeiou":

# %%
x = "Hello"
print(type(x))
# Out:
# <class 'str'>

# %%
x = 10
print(type(x))
# Out:
# <class 'int'>

# %%
x=10
if(x>0):
  print("positive")
if(x<0):
  print("negative")
if(x==0):
  print("zero")
# Out:
# positive

# %%
n=10
if n%2==0:
  print("Even")
else:
  print("false")
# Out:
# Even

# %%
age=23
if(age>=18):
  print("Eligible")
else:
  print("Not Eligible")
# Out:
# Eligible

# %%
n=2
c=6
if(n>c):
  print("n is max")
else:
  print("c is max")
# Out:
# c is max

# %%
mark=45
if mark>=45:
  print("pass")
else:
  print("fail")
# Out:
# pass

# %%
year=1947
if year%400==0:
  print("leap year")
elif year%100==0:
  print("not a leap year")
elif year%4==0:
  print("leap year")
else:
  print("not leap year")
# Out:
# not leap year

# %%
n=15
if(n%3==0)and(n%5==0):
  print("n is divisible by 3 and 5")
else:
  print("not divisible by 3 and 5")
# Out:
# n is divisible by 3 and 5

# %%
a=8
b=3
c=4
if (a<b)and(a<c):
  print("a is small")
elif(b<a)and(b<c):
  print("b is small")
else:
  print("c is small")
# Out:
# b is small

# %%
n=6
if n>0:
  print("positive")
else:
  print("negative")
if n%2==0:
  print("Even")
else:
  print("odd")
# Out:
# positive
# Even

# %%
marks=40
if marks>=90:
  print("A")
elif marks>=80:
  print("B")
elif marks>=70:
  print("C")
elif marks>=60:
  print("D")
else:
  print("F")
# Out:
# F
