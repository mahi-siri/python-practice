# %% [markdown]
# <a href="https://colab.research.google.com/github/mahi-siri/python-practice/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input())
arr=list(map(int,input().split()))
print(max(arr))
print(min(arr))
# Out:
# 5
# 1 2 3 4 5
# 5
# 1

# %%
arr=list(map(int,input().split()))
print(sum(arr))
# Out:
# 1 2 3 4 5
# 15

# %%
arr=list(map(int,input().split()))
total=0
for i in arr:
  total+=i
print(total)
# Out:
# 1 2 3 4 5
# 15

# %%
n=int(input())
arr=list(map(int,input().split()))
arr=list(set(arr))
arr.sort()
print(arr[-2])
# Out:
# 5
# 2 3 6 7 2
# 6

# %%
n=int(input())
arr=list(map(int,input().split()))
arr=arr[::-1]
print(*arr)
# Out:
# 5
# 1 2 3 4 5
# 5 4 3 2 1

# %%
n=int(input())
arr=list(map(int,input().split()))
arr=list(set(arr))
arr.sort()kit is wrong
print(*arr)
# Out:
# 5
# 1 2 2 3 4
# 1 2 3 4

# %%
n=int(input())
arr=list(map(int,input().split()))
result=[]
for i in arr:
    if i not in result:
       result.append(i)
print(*result)
# Out:
# 5
# 1 2 2 3 3
# 1 2 3

# %%
arr=list(map(int,input().split()))
even=0
odd=0
for i in arr:
  if i%2==0:
    even+=1
  else:
    odd+=1
print(even)
print(odd)
# Out:
# 1 2 3 4 5 6
# 3
# 3

# %%
arr=list(set(map(int,input().split())))
result=[]
avg=sum(arr)/len(arr)
for i in arr:
    if i>avg:
       result.append(i)
print(result)
# Out:
# 1 2 3 4 5  8 8
# [4, 5, 8]

# %%
s=input()
if s==s[::-1]:
  print("True")
else:
  print("False")
# Out:
# pravinya
# False

# %%
s=input().lower()
vowel=0
consonants=0
for ch in s:
  if ch.isalpha():
    if ch in "aeiou":
      vowel+=1
    else:
      consonants+=1
print(vowel,consonants)
# Out:
# pravinya
# 3 5

# %%
s=input().split()
result=[]
for w in s:
  result.append(w[::-1])
print(*result)
# Out:
# hello world
# olleh dlrow

# %%
list=input()
freq={}
for ch in list:
  freq[ch]=freq.get(ch,0)+1
print(freq)
# Out:
# banana
# {'b': 1, 'a': 3, 'n': 2}

# %%
s=input()
result=""
for ch in s:
    if ch.isalpha():
       result+=ch
print(result)
# Out:
# f3gfd5r
# fgfdr

# %%
s1=input().replace(" ","").lower()
s2=input().replace(" ","").lower()
if sorted(s1)==sorted(s2):
  print("true")
else:
  print("false")
# Out:
# listen
# etnsil
# true

# %%
s=input().split()
longest=""
for w in s:
  if len(w)>len(longest):
    longest=w
print(longest)
# Out:
# I love programming
# programming

# %%
keys=input().split()
values=input().split()
result=dict(zip(keys,values))
print(result)
# Out:
# name age marks
# siri 18 100
# {'name': 'siri', 'age': '18', 'marks': '100'}

# %%
n=int(input())
d={}
for i in range(n) :
  k,v=input().split()
  d[k]=int(v)
for k,v in sorted(d.items(),key=lambda x:x[1]):
     print(k,v,end=" ")
# Out:
# 3
# a 2
# b 3
# c 1
# c 1 a 2 b 3

# %%
n=int(input())
d={}
for i in range(n):
  k,v=input().split()
  d[k]=v
print(d)
# Out:
# 2
# 1 a
# 2 r
# {'1': 'a', '2': 'r'}

# %%
s=input().split()
d={}
for w in s:
  d[w]=d.get(w,0)+1
print(d)
# Out:
# I I Love Love Programming
# {'I': 2, 'Love': 2, 'Programming': 1}

# %%
n=int(input())
arr=list(map(int,input().split()))
result=[]
for i in arr:
  if i!=0:
    result.append(i)
for i in arr:
  if i==0:
    result.append(i)
print(*result)
# Out:
# 5
# 1 2 3 0 6
# 1 2 3 6 0

# %%
n=int(input())
arr=list(map(int,input().split()))
k=int(input())
k=k%n
result=arr[-k:]+arr[:-k]
print(*result)
# Out:
# 5
# 2 3 4 5 6
# 2
# 5 6 2 3 4

# %%
n=int(input())
arr=list(map(int,input().split()))
expected=n*(n+1)//2
result=sum(arr)
print (abs(expected-result))
# Out:
# 4
# 1 3 4 5
# 3

# %%
n=int(input())
arr=list(map(int,input().split()))
target=int(input())
for i in range(n):
  for j in range(i+1,n):
    if target==(arr[i]+arr[j]):
        print(arr[i],arr[j])
# Out:
# 5
# 2 3 4 1 6
# 5
# 2 3
# 4 1

# %%
n=int(input())
arr=list(map(int,input().split()))
leaders=[]
max_right=float('-inf')
for i in range(n-1,-1,-1):
  if arr[i]>max_right:
     leaders.append(arr[i])
     max_right=arr[i]
leaders.reverse()
print(*leaders)
# Out:
# 5
# 16 17 5 4 2
# 17 5 4 2

# %%
s = input()

words = len(s.split())
digits = 0
specials = 0

for ch in s:
    if ch.isdigit():
        digits += 1
    elif not ch.isalpha() and not ch.isspace():
        specials += 1

print(words, digits, specials)
# Out:
# h2e$$
# 1 1 2

# %%
n = int(input())

for num in range(2, n + 1):
    is_prime = True
    for i in range(2, num):
        if num % i == 0:
            is_prime = False
            break
    if is_prime:
        print(num)
# Out:
# 10
# 2
# 3
# 5
# 7

# %%
n=int(input())
for num in range(2,n+1):
    is_prime=True
    for i in range(2,num):
        if num%i==0:
            is_prime=False
            break
    if is_prime:
        print(num)
# Out:
# 10
# 2
# 3
# 5
# 7
